# %% [markdown]
# # HSV colorspace

# %% [markdown]
# ### Import resources

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

import numpy as np
import cv2

# %matplotlib inline

# %% [markdown]
# ### Read in RGB image

# %%
# Read in the image
image = mpimg.imread('images/car_green_screen2.jpg')

plt.imshow(image)

# %% [markdown]
# ### RGB threshold
#
# Visualize the green threshold you defined in the previous, consistent green color case.

# %%
# Define our color selection boundaries in RGB values
lower_green = np.array([0,180,0]) 
upper_green = np.array([100,255,100])

# Define the masked area
mask = cv2.inRange(image, lower_green, upper_green)

# Mask the image to let the car show through
masked_image = np.copy(image)

masked_image[mask != 0] = [0, 0, 0]

# Display it!
plt.imshow(masked_image)

# %% [markdown]
# ### Convert to HSV

# %%
# Convert to HSV
hsv = cv2.cvtColor(image, cv2.COLOR_RGB2HSV)

# HSV channels
h = hsv[:,:,0]
s = hsv[:,:,1]
v = hsv[:,:,2]

# Visualize the individual color channels
f, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(20,10))
ax1.set_title('H channel')
ax1.imshow(h, cmap='gray')
ax2.set_title('S channel')
ax2.imshow(s, cmap='gray')
ax3.set_title('V channel')
ax3.imshow(v, cmap='gray')

# %% [markdown]
# ### TODO: Mask the green area using HSV color space

# %%
## TODO: Define the color selection boundaries in HSV values

## TODO: Define the masked area and mask the image
# Don't forget to make a copy of the original image to manipulate

# %%
## TODO: Define the color selection boundaries in HSV values
lower_h = np.array([120,0,0]) 
upper_h = np.array([255,255,255])

# Define the masked area
mask = cv2.inRange(image, lower_h, upper_h)

# Mask the image to let the car show through
masked_image = np.copy(image)

masked_image[mask == 0] = [0, 0, 0]

# Display it!
plt.imshow(masked_image)

# %%
## TODO: Define the color selection boundaries in HSV values
# Visualize the individual different masks
f, axs = plt.subplots(2, 3, figsize=(20,10))

lower_h = np.array([0,0,0]) 
upper_h = np.array([255,255,255])
mask = cv2.inRange(image, lower_h, upper_h)
masked_image = np.copy(image)
masked_image[mask == 0] = [0, 0, 0]
# Display it!
axs[0,0].set_title('Mask 1')
axs[0,0].imshow(masked_image)

lower_h = np.array([25,0,0]) 
upper_h = np.array([255,255,255])
mask = cv2.inRange(image, lower_h, upper_h)
masked_image = np.copy(image)
masked_image[mask == 0] = [0, 0, 0]
# Display it!
axs[0,1].set_title('Mask 2')
axs[0,1].imshow(masked_image)

lower_h = np.array([50,0,0]) 
upper_h = np.array([255,255,255])
mask = cv2.inRange(image, lower_h, upper_h)
masked_image = np.copy(image)
masked_image[mask == 0] = [0, 0, 0]
# Display it!
axs[0,2].set_title('Mask 3')
axs[0,2].imshow(masked_image)

lower_h = np.array([75,0,0]) 
upper_h = np.array([255,255,255])
mask = cv2.inRange(image, lower_h, upper_h)
masked_image = np.copy(image)
masked_image[mask == 0] = [0, 0, 0]
# Display it!
axs[1,0].set_title('Mask 4')
axs[1,0].imshow(masked_image)

lower_h = np.array([100,0,0]) 
upper_h = np.array([255,255,255])
mask = cv2.inRange(image, lower_h, upper_h)
masked_image = np.copy(image)
masked_image[mask == 0] = [0, 0, 0]
# Display it!
axs[1,1].set_title('Mask 5')
axs[1,1].imshow(masked_image)

lower_h = np.array([125,0,0]) 
upper_h = np.array([255,255,255])
mask = cv2.inRange(image, lower_h, upper_h)
masked_image = np.copy(image)
masked_image[mask == 0] = [0, 0, 0]
# Display it!
axs[1,2].set_title('Mask 6')
axs[1,2].imshow(masked_image)
